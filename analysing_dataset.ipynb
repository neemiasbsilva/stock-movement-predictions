# %% [markdown]
# # Analysing and Preprocessing the Dataset

# %% [markdown]
# ## Import Librarys

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler

# %matplotlib inline

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("../stock-market-prediction-lstm/MSFT.csv")

df.head()
# Out:
#          Date      Open     High       Low     Close  Adj Close    Volume
# 0  2000-01-03  58.68750  59.3125  56.00000  58.28125  37.199776  53228400
# 1  2000-01-04  56.78125  58.5625  56.12500  56.31250  35.943153  54119000
# 2  2000-01-05  55.56250  58.1875  54.68750  56.90625  36.322121  64059600
# 3  2000-01-06  56.09375  56.9375  54.18750  55.00000  35.105415  54976600
# 4  2000-01-07  54.31250  56.1250  53.65625  55.71875  35.564171  62013600

# %% [markdown]
# ## Analysing Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5217 entries, 0 to 5216
# Data columns (total 7 columns):
# Date         5217 non-null object
# Open         5217 non-null float64
# High         5217 non-null float64
# Low          5217 non-null float64
# Close        5217 non-null float64
# Adj Close    5217 non-null float64
# Volume       5217 non-null int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 285.4+ KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  5217.000000  5217.000000  5217.000000  5217.000000  5217.000000
# mean     47.354633    47.853204    46.846430    47.362718    41.077895
# std      38.423281    38.826068    37.976797    38.437416    40.349855
# min      15.200000    15.620000    14.870000    15.150000    11.638612
# 25%      26.655001    26.930000    26.375000    26.629999    19.113081
# 50%      30.030001    30.370001    29.790001    30.030001    22.467312
# 75%      48.410000    48.919998    47.869999    48.450001    42.433563
# max     229.270004   232.860001   227.350006   231.649994   231.649994
#
#              Volume
# count  5.217000e+03
# mean   5.482613e+07
# std    3.132790e+07
# min    7.425600e+06
# 25%    3.278550e+07
# 50%    5.008400e+07
# 75%    6.828380e+07
# max    5.910522e+08

# %%
df.shape
# Out:
# (5217, 7)

# %%
plt.figure(figsize=(18,9))
plt.plot(range(df.shape[0]), (df["Open"]), color='b', label='Open Price')
# plt.legend()

plt.xticks(range(0, df.shape[0], 100), df["Date"].loc[::100], rotation=45)
plt.xlabel("Date", fontsize=18)
plt.ylabel("Open Price", fontsize=18)
# Out:
# Text(0, 0.5, 'Open Price')

# %%
plt.figure(figsize=(18,9))
plt.plot(range(df.shape[0]), (df["High"]), color='r')
plt.xticks(range(0, df.shape[0], 100), df["Date"].loc[::100], rotation=45)
plt.xlabel("Date", fontsize=18)
plt.ylabel("High Price", fontsize=18)
# Out:
# Text(0, 0.5, 'High Price')

# %%
plt.figure(figsize=(18,9))
plt.plot(range(df.shape[0]), (df["Low"]), color ='orange')
plt.xticks(range(0, df.shape[0], 100), df["Date"].loc[::100], rotation=45)
plt.xlabel("Date", fontsize=18)
plt.ylabel("Low Price", fontsize=18)
# Out:
# Text(0, 0.5, 'Low Price')

# %%
plt.figure(figsize=(18,9))
plt.plot(range(df.shape[0]), (df["Close"]), color='g')
plt.xticks(range(0, df.shape[0], 100), df["Date"].loc[::100], rotation=45)
plt.xlabel("Date", fontsize=18)
plt.ylabel("Close Price", fontsize=18)
# Out:
# Text(0, 0.5, 'Close Price')

# %%
plt.figure(figsize=(18,9))
plt.plot(range(df.shape[0]), (df["Adj Close"]), color='magenta')
plt.xticks(range(0, df.shape[0], 100), df["Date"].loc[::100], rotation=45)
plt.xlabel("Date", fontsize=18)
plt.ylabel("Adj Close Price", fontsize=18)
# Out:
# Text(0, 0.5, 'Adj Close Price')
